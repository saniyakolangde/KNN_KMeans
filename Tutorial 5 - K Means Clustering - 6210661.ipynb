# %% [markdown]
# # Tutorial 5
#
# # K Means Clustering with Python
#
#
#
# ## Method Used
#
# K Means Clustering is an unsupervised learning algorithm that tries to cluster data based on their similarity. Unsupervised learning means that there is no outcome to be predicted, and the algorithm just tries to find patterns in the data. In k means clustering, we have the specify the number of clusters we want the data to be grouped into. The algorithm randomly assigns each observation to a cluster, and finds the centroid of each cluster. Then, the algorithm iterates through two steps:
# Reassign data points to the cluster whose centroid is closest. Calculate new centroid of each cluster. These two steps are repeated till the within cluster variation cannot be reduced any further. The within cluster variation is calculated as the sum of the euclidean distance between the data points and their respective cluster centroids.
# We have already seen an example in the lecture.

# %% [markdown]
# ## Import Libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Create some Data artifical data
# # n_samples=200
# , n_features=2,
#                            centers=4, cluster_std=1.8,random_state=101
#
#         data[0].shape -->200,2     numpyarray

# %%
from sklearn.datasets import make_blobs

# %% [markdown]
# # Create Data
# ## data = make_blobs(n_samples=200, n_features=2,
#                            #
#     ## centers=4, cluster_std=1.8,random_state=101)
#     data[0] 200 samples with two features
#     data[1] cluster it belongs to 1-4

# %%
data=make_blobs(n_samples=200, n_features=2, centers=4, cluster_std=1.8,random_state=101 )

# %% [markdown]
# ## Visualize Data

# %%
#display data
data
# Out:
# (array([[-6.42884095e+00,  1.01411174e+01],
#         [ 5.86867888e+00,  5.20110356e+00],
#         [-3.76109375e-01,  3.26427943e+00],
#         [ 2.16679181e+00,  9.56300522e+00],
#         [ 5.09508570e+00,  7.20752718e+00],
#         [-1.08788882e+01, -6.11318040e+00],
#         [ 2.03405554e+00,  9.76664755e+00],
#         [-1.71798771e+00,  1.41401140e+00],
#         [ 1.16911341e+00,  8.24556988e+00],
#         [-1.35185444e+00,  3.13245345e+00],
#         [-6.18548214e+00,  9.67406555e+00],
#         [-1.19856602e+00,  2.50408937e+00],
#         [ 2.90296863e+00,  7.91251003e+00],
#         [ 2.39250023e+00,  5.38173971e+00],
#         [-5.27545147e+00,  9.63836659e+00],
#         [-5.66814687e-01,  5.60262755e-02],
#         [ 5.97336628e+00,  5.87172022e+00],
#         [-2.31355268e+00,  5.23980092e-01],
#         [-1.01344756e+01, -3.43130837e+00],
#         [-4.54082629e+00,  1.13920174e+01],
#         [-1.04155833e+01, -5.67545836e+00],
# ...

# %%
data[0].shape
# Out:
# (200, 2)

# %%
#display the 2nd array
data[1]
# Out:
# array([3, 2, 0, 2, 2, 1, 2, 0, 2, 0, 3, 0, 2, 2, 3, 0, 2, 0, 1, 3, 1, 0,
#        0, 1, 3, 1, 1, 0, 2, 2, 3, 1, 2, 0, 0, 3, 1, 1, 1, 2, 1, 3, 3, 3,
#        0, 3, 3, 0, 1, 2, 0, 3, 2, 0, 1, 3, 0, 0, 3, 2, 1, 2, 1, 3, 2, 0,
#        1, 2, 2, 1, 2, 0, 1, 3, 1, 2, 2, 0, 3, 0, 0, 1, 2, 1, 0, 0, 0, 3,
#        2, 1, 1, 1, 1, 3, 0, 1, 2, 3, 1, 2, 0, 1, 0, 0, 2, 0, 1, 2, 1, 1,
#        0, 3, 3, 2, 1, 2, 3, 3, 2, 3, 0, 3, 0, 3, 0, 2, 3, 0, 1, 3, 3, 3,
#        0, 1, 1, 3, 2, 3, 2, 0, 1, 2, 1, 3, 3, 2, 0, 1, 3, 3, 3, 3, 0, 2,
#        0, 3, 2, 2, 2, 0, 2, 0, 0, 3, 1, 3, 0, 2, 3, 0, 2, 0, 3, 3, 0, 3,
#        2, 2, 1, 2, 3, 1, 1, 3, 1, 1, 1, 1, 1, 0, 1, 2, 2, 3, 1, 0, 2, 2,
#        1, 0])

# %%
plt.scatter(data[0][:,0], data[0][:,1], c=data[1], cmap = 'PiYG')

# %% [markdown]
# ## Creating the Clusters

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)

# %% [markdown]
# ## kmeans is the object

# %%
kmeans.fit(data[0])
# Out:
# KMeans(n_clusters=4)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 5.10828057,  4.90813315],
#        [-9.18960987, -8.53584776],
#        [-2.41575022,  8.84918197],
#        [ 1.56319372,  0.51379481],
#        [ 0.62410762,  5.30366491],
#        [ 3.92332853,  8.33708576],
#        [-9.67203831, -5.13061964],
#        [-5.43564562,  7.56223985],
#        [-1.58936006,  1.9044536 ]])

# %%
kmeans.labels_
# Out:
# array([7, 0, 8, 5, 5, 6, 5, 8, 5, 8, 7, 8, 5, 4, 7, 8, 0, 8, 6, 2, 6, 3,
#        4, 1, 7, 1, 1, 3, 5, 0, 2, 1, 0, 3, 8, 7, 6, 6, 1, 3, 6, 2, 2, 2,
#        8, 4, 7, 4, 1, 4, 3, 7, 0, 3, 6, 4, 4, 3, 7, 5, 1, 4, 6, 2, 5, 8,
#        6, 0, 5, 6, 5, 4, 6, 8, 6, 0, 5, 8, 7, 8, 4, 6, 5, 6, 3, 8, 8, 7,
#        4, 6, 1, 6, 6, 4, 4, 1, 5, 7, 6, 0, 8, 6, 4, 8, 4, 4, 6, 5, 1, 6,
#        0, 2, 7, 5, 1, 0, 2, 7, 4, 2, 4, 7, 8, 7, 8, 0, 7, 8, 1, 2, 7, 2,
#        3, 1, 6, 7, 0, 8, 5, 3, 1, 0, 6, 2, 2, 4, 4, 1, 7, 7, 2, 2, 8, 0,
#        3, 7, 4, 5, 5, 3, 5, 3, 8, 7, 6, 7, 8, 5, 2, 3, 5, 3, 7, 4, 4, 7,
#        5, 4, 1, 4, 2, 1, 1, 2, 6, 1, 6, 1, 1, 3, 6, 5, 5, 7, 6, 4, 5, 5,
#        6, 3], dtype=int32)

# %%
f, (ax1, ax2) = plt.subplots(1,2,sharey=True, figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='Pastel1')
ax2.set_title('Original')
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='Pastel1')

# %% [markdown]
# # https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html

# %%
sse={}
for k in range(1,10):
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(data[0])
    sse[k] = kmeans.inertia_ #Inertia: Sum of distances of samples to their closest cluster center
plt.figure()
plt.plot(list(sse.keys()),list(sse.values()))
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
plt.show()

# %% [markdown]
# The graph bends down from number 4, this shows that the number of errors is decreasing from 4. Hence, it should use 4 for the K-means number.
